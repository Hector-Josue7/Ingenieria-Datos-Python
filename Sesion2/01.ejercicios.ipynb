# %%
import random

# %%
lista = [random.randint(1,100) for i in range(1,100)]
print(lista)
# Out:
# [88, 79, 27, 80, 2, 31, 49, 79, 100, 21, 95, 38, 97, 87, 24, 32, 34, 38, 21, 81, 67, 73, 94, 92, 8, 30, 52, 20, 87, 51, 64, 24, 59, 68, 7, 86, 80, 3, 2, 64, 87, 28, 87, 84, 24, 60, 42, 75, 54, 76, 83, 24, 81, 90, 73, 56, 93, 95, 22, 50, 74, 71, 35, 84, 6, 68, 35, 76, 8, 84, 19, 24, 11, 60, 14, 78, 60, 93, 18, 53, 2, 87, 45, 65, 84, 45, 97, 20, 45, 24, 60, 68, 41, 79, 46, 33, 4, 53, 34]

# %%
# funcion para sumar numeros pares -> operador % //. 53%2 = 1
def suma_pares(lista):
    sum =0
    for item in lista:
        if item % 2 ==0:
            sum = sum + item
    return sum


print(suma_pares(lista))
# Out:
# 2726

# %%
# funcion para buscar un elemento en una lista
def buscar_elemento(lista, elemento):
    
    for item in lista:
        if item == elemento:
            return True
    
    return False


print(buscar_elemento(lista, 86))
# Out:
# True

# %%
# Crear una función que reciba una lista de palabras y retorne un diccionario con 
# la cantidad de veces que aparece cada palabra.
def contar_palabras(lista):
    dict_frec ={}
    for palabra in lista: 
        if palabra in dict_frec:
            dict_frec[palabra] = dict_frec[palabra] + 1
        else: 
            dict_frec[palabra] =1
    return dict_frec


palabras = ["python", "java", "python", "c++", "python", "java"]
resultado = contar_palabras(palabras)
print(resultado)
# Out:
# {'python': 3, 'java': 2, 'c++': 1}

# %%
# Crear una función que reciba un diccionario donde las llaves sean nombres y los valores sean notas.
# Debe retornar el nombre del alumno con la nota más alta
def mejor_alumno(diccionario):
    nombre =''
    nota_aux = -1

    for nombre_dict, nota in diccionario.items():
        if nota > nota_aux: 
            nota_aux = nota
            nombre = nombre_dict
    return nombre

notas = {"Ana": 15, "Luis": 18, "María": 17, "Pedro": 19}
print(mejor_alumno(notas))
# Out:
# Pedro
